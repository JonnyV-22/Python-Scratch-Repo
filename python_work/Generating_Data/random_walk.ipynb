# %%
import matplotlib.pyplot as plt
from random import choice
'''Choice selects a random value from a list'''

class RandomWalk:
    '''Class to generate a random walk'''
    def __init__(self,num_points=200_000):
        self.num_points = num_points
        
        self.x_values = [0]
        self.y_values = [0]
        
    def fill_walk(self):
        '''Calculate the points in a walk'''
        while len(self.x_values) < self.num_points:
            x_direction = choice([1,-1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_distance * x_direction
            
            y_direction = choice([1,-1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_distance * y_direction
            
            if x_step == 0 and y_step == 0:
                continue
            
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)
            
rw = RandomWalk()
rw.fill_walk()

plt.style.use('classic')
fig, ax = plt.subplots(figsize=(20,12))
point_numbers = range(rw.num_points)
ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.GnBu, edgecolors='none', s=15)
ax.scatter(0, 0, c='green', edgecolors='none',s=75)
ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none', s=75)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.set_aspect('equal')

plt.show()

# %%
import matplotlib.pyplot as plt
from random import choice
'''Choice selects a random value from a list'''

class RandomWalk:
    '''Class to generate a random walk'''
    def __init__(self,num_points=5000):
        self.num_points = num_points
        
        self.x_values = [0]
        self.y_values = [0]
        
        
    def get_step(self):
        while len(self.x_values) < self.num_points:
            direction = choice([1,-1])
            distance = choice([0, 1, 2, 3, 4])
            step = distance * direction
            return step
            

    def fill_walk(self):
        '''Calculate the points in a walk'''
        while len(self.x_values) < self.num_points:
            x_step = self.get_step()
            y_step = self.get_step()
            
            if x_step == 0 and y_step == 0:
                continue

            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)
            

        
            
rw = RandomWalk()
rw.fill_walk()

plt.style.use('classic')
fig, ax = plt.subplots(figsize=(20,12))
ax.plot(rw.x_values, rw.y_values, linewidth=3)


ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.set_aspect('equal')

plt.show()
